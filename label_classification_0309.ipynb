# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

train_df = pd.read_csv("/content/drive/MyDrive/DL_Project/train_df.csv")
print(len(train_df["label"].unique()))
label_list = train_df["label"].unique().tolist()
len(label_list)
# Out:
# 88
# 88

# %%
import os 
import shutil

def Folder(directory):
  try:
    if not os.path.exists(directory):
      os.makedirs(directory)
  except OSError:
      print('Error: Creating directory' + directory)  


for i in range(len(label_list)):
  Folder(f'./train/{label_list[i]}')

# %%
train_folder = os.listdir('./train/')

for i in range(len(train_folder) - 88):
  if train_folder[i][0] == 1:
    file_source = f'./train/{train_folder[i]}'
    file_destination = f'./train/{label}/'
    shutil.move(file_source,file_destination)
